# %%
# Update sklearn to prevent version mismatches
# !pip install sklearn --upgrade
# Out:
# Requirement already satisfied: sklearn in /opt/anaconda3/lib/python3.8/site-packages (0.0)
# Requirement already satisfied: scikit-learn in /opt/anaconda3/lib/python3.8/site-packages (from sklearn) (0.23.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/anaconda3/lib/python3.8/site-packages (from scikit-learn->sklearn) (2.2.0)
# Requirement already satisfied: scipy>=0.19.1 in /opt/anaconda3/lib/python3.8/site-packages (from scikit-learn->sklearn) (1.6.2)
# Requirement already satisfied: joblib>=0.11 in /opt/anaconda3/lib/python3.8/site-packages (from scikit-learn->sklearn) (1.0.1)
# Requirement already satisfied: numpy>=1.13.3 in /opt/anaconda3/lib/python3.8/site-packages (from scikit-learn->sklearn) (1.19.5)

# %%
# install joblib. This will be used to save your model. 
# Restart your kernel after installing 
# !pip install joblib
# Out:
# Requirement already satisfied: joblib in /opt/anaconda3/lib/python3.8/site-packages (1.0.1)

# %%
import tensorflow as tf
import pandas as pd
import os

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("Resources/exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %% [markdown]
# # Select your features (columns)

# %%
# Set features. This will also be used as your x values.
target = df["koi_disposition"]
target_names = ["negative" , "positive"]

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
data = df.drop("koi_disposition", axis =1)
feature_names = data.columns
data.head()
# Out:
#    koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 0              0              0              0              0   54.418383
# 1              0              1              0              0   19.899140
# 2              0              1              0              0    1.736952
# 3              0              0              0              0    2.525592
# 4              0              0              0              0    4.134435
#
#    koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 0     2.479000e-04    -2.479000e-04   162.513840          0.003520
# 1     1.490000e-05    -1.490000e-05   175.850252          0.000581
# 2     2.630000e-07    -2.630000e-07   170.307565          0.000115
# 3     3.760000e-06    -3.760000e-06   171.595550          0.001130
# 4     1.050000e-05    -1.050000e-05   172.979370          0.001900
#
#    koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0         -0.003520  ...             -81      4.467           0.064
# 1         -0.000581  ...            -176      4.544           0.044
# 2         -0.000115  ...            -174      4.564           0.053
# 3         -0.001130  ...            -211      4.438           0.070
# 4         -0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 40 columns]

# %%
# Split the data using train_test_split
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=42)

# %%
X_train.head()
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 6122              0              0              0              0    6.768901
# 6370              0              1              0              1    0.733726
# 2879              1              0              0              0    7.652707
# 107               0              0              0              0    7.953547
# 29                0              0              0              0    4.959319
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 6122     7.380000e-05    -7.380000e-05   133.077240          0.008440
# 6370     6.060000e-06    -6.060000e-06   132.020050          0.007950
# 2879     6.540000e-05    -6.540000e-05   134.460380          0.006190
# 107      1.910000e-05    -1.910000e-05   174.662240          0.001820
# 29       5.150000e-07    -5.150000e-07   172.258529          0.000083
#
#       koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 6122         -0.008440  ...            -171      4.327           0.153
# 6370         -0.007950  ...            -175      4.578           0.033
# 2879         -0.006190  ...            -189      4.481           0.050
# 107          -0.001820  ...             -85      4.536           0.056
# 29           -0.000083  ...             -77      4.359           0.110
#
#       koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 6122          -0.187     1.125          0.310         -0.207  294.40472
# 6370          -0.187     0.797          0.211         -0.056  284.50391
# 2879          -0.200     0.963          0.290         -0.097  295.50211
# 107           -0.016     0.779          0.023         -0.049  291.15878
# 29            -0.110     1.082          0.173         -0.130  292.16705
#
#             dec  koi_kepmag
# 6122  39.351681      14.725
# 6370  42.463860      15.770
# 2879  38.983540      13.099
# 107   40.750271      15.660
# 29    48.727589      15.263
#
# [5 rows x 40 columns]

# %% [markdown]
# # Pre-processing
#
# Scale the data using the MinMaxScaler and perform some feature selection

# %%
# Scale your data


from sklearn.preprocessing import MinMaxScaler

X_scale = MinMaxScaler().fit(X_train)

X_train_scaled = X_scale.transform(X_train)
X_test_scaled = X_scale.transform(X_test)

# %% [markdown]
# # Train the Model

# %%
from sklearn.neighbors import KNeighborsClassifier

train_scores = []
test_scores = []
for k in range (1,20, 2):
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train_scaled, y_train)
    train_score = knn.score(X_train_scaled, y_train)
    test_score = knn.score(X_test_scaled, y_test)
    train_scores.append(train_score)
    test_scores.append(test_score)
    print(f"K: {k}, Train/Test Score: {train_score:.3f}/{test_score:.3f}")
# Out:
# K: 1, Train/Test Score: 1.000/0.790
# K: 3, Train/Test Score: 0.897/0.811
# K: 5, Train/Test Score: 0.878/0.820
# K: 7, Train/Test Score: 0.866/0.823
# K: 9, Train/Test Score: 0.856/0.828
# K: 11, Train/Test Score: 0.848/0.828
# K: 13, Train/Test Score: 0.849/0.822
# K: 15, Train/Test Score: 0.841/0.824
# K: 17, Train/Test Score: 0.838/0.827
# K: 19, Train/Test Score: 0.836/0.824

# %%
import matplotlib.pyplot as plt
plt.plot(range(1,20,2), train_scores, marker='o')
plt.plot(range(1,20,2), test_scores, marker='x')
plt.xlabel('k neighbors')
plt.ylabel('Testing accuracy Score')
plt.show()

# %%
model_knn = KNeighborsClassifier(n_neighbors = 19)
model_knn.fit(X_train_scaled, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=19)

# %%
print(f"Training Data Score: {knn.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {knn.score(X_test_scaled, y_test)}")
# Out:
# Training Data Score: 0.8363532328819379
# Testing Data Score: 0.8243707093821511

# %%
predictions = knn.predict(X_test_scaled)
print(predictions)
# Out:
# ['FALSE POSITIVE' 'CANDIDATE' 'FALSE POSITIVE' ... 'CONFIRMED' 'CANDIDATE'
#  'CONFIRMED']

# %% [markdown]
# # Hyperparameter Tuning
#
# Use `GridSearchCV` to tune the model's parameters

# %%
from pprint import pprint
print('Parameters:\n')
pprint(model_knn.get_params())
# Out:
# Parameters:
#
# {'algorithm': 'auto',
#  'leaf_size': 30,
#  'metric': 'minkowski',
#  'metric_params': None,
#  'n_jobs': None,
#  'n_neighbors': 19,
#  'p': 2,
#  'weights': 'uniform'}

# %%
# Create the GridSearchCV model
from sklearn.model_selection import GridSearchCV
param_grid = {'n_neighbors': [ 7,9,11,15,17,19,21,23,25,27,29],
              'weights': ['uniform', 'distance'],
              'p': [1,2]}

grid = GridSearchCV(model_knn, param_grid, verbose=3 )

# %%
# Train the model with GridSearch
grid.fit(X_train_scaled, y_train)
# Out:
# Fitting 5 folds for each of 44 candidates, totalling 220 fits
# [CV] n_neighbors=7, p=1, weights=uniform .............................
# [CV] . n_neighbors=7, p=1, weights=uniform, score=0.862, total=   0.1s
# [CV] n_neighbors=7, p=1, weights=uniform .............................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [CV] . n_neighbors=7, p=1, weights=uniform, score=0.832, total=   0.1s
# [CV] n_neighbors=7, p=1, weights=uniform .............................
# [CV] . n_neighbors=7, p=1, weights=uniform, score=0.830, total=   0.1s
# [CV] n_neighbors=7, p=1, weights=uniform .............................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.3s remaining:    0.0s
# [CV] . n_neighbors=7, p=1, weights=uniform, score=0.825, total=   0.1s
# [CV] n_neighbors=7, p=1, weights=uniform .............................
# [CV] . n_neighbors=7, p=1, weights=uniform, score=0.838, total=   0.1s
# [CV] n_neighbors=7, p=1, weights=distance ............................
# [CV]  n_neighbors=7, p=1, weights=distance, score=0.863, total=   0.1s
# [CV] n_neighbors=7, p=1, weights=distance ............................
# [CV]  n_neighbors=7, p=1, weights=distance, score=0.830, total=   0.1s
# [CV] n_neighbors=7, p=1, weights=distance ............................
# [CV]  n_neighbors=7, p=1, weights=distance, score=0.829, total=   0.1s
# [CV] n_neighbors=7, p=1, weights=distance ............................
# [CV]  n_neighbors=7, p=1, weights=distance, score=0.828, total=   0.1s
# [CV] n_neighbors=7, p=1, weights=distance ............................
# [CV]  n_neighbors=7, p=1, weights=distance, score=0.840, total=   0.1s
# [CV] n_neighbors=7, p=2, weights=uniform .............................
# [CV] . n_neighbors=7, p=2, weights=uniform, score=0.828, total=   0.1s
# [CV] n_neighbors=7, p=2, weights=uniform .............................
# [CV] . n_neighbors=7, p=2, weights=uniform, score=0.807, total=   0.1s
# [CV] n_neighbors=7, p=2, weights=uniform .............................
# [CV] . n_neighbors=7, p=2, weights=uniform, score=0.810, total=   0.1s
# [CV] n_neighbors=7, p=2, weights=uniform .............................
# [CV] . n_neighbors=7, p=2, weights=uniform, score=0.807, total=   0.1s
# [CV] n_neighbors=7, p=2, weights=uniform .............................
# [CV] . n_neighbors=7, p=2, weights=uniform, score=0.809, total=   0.1s
# [CV] n_neighbors=7, p=2, weights=distance ............................
# [CV]  n_neighbors=7, p=2, weights=distance, score=0.827, total=   0.1s
# [CV] n_neighbors=7, p=2, weights=distance ............................
# [CV]  n_neighbors=7, p=2, weights=distance, score=0.806, total=   0.1s
# [CV] n_neighbors=7, p=2, weights=distance ............................
# [CV]  n_neighbors=7, p=2, weights=distance, score=0.807, total=   0.1s
# [CV] n_neighbors=7, p=2, weights=distance ............................
# [CV]  n_neighbors=7, p=2, weights=distance, score=0.810, total=   0.1s
# [CV] n_neighbors=7, p=2, weights=distance ............................
# [CV]  n_neighbors=7, p=2, weights=distance, score=0.807, total=   0.1s
# [CV] n_neighbors=9, p=1, weights=uniform .............................
# [CV] . n_neighbors=9, p=1, weights=uniform, score=0.865, total=   0.1s
# [CV] n_neighbors=9, p=1, weights=uniform .............................
# [CV] . n_neighbors=9, p=1, weights=uniform, score=0.838, total=   0.1s
# [CV] n_neighbors=9, p=1, weights=uniform .............................
# [CV] . n_neighbors=9, p=1, weights=uniform, score=0.834, total=   0.1s
# [CV] n_neighbors=9, p=1, weights=uniform .............................
# [CV] . n_neighbors=9, p=1, weights=uniform, score=0.812, total=   0.1s
# [CV] n_neighbors=9, p=1, weights=uniform .............................
# [CV] . n_neighbors=9, p=1, weights=uniform, score=0.840, total=   0.1s
# [CV] n_neighbors=9, p=1, weights=distance ............................
# [CV]  n_neighbors=9, p=1, weights=distance, score=0.863, total=   0.1s
# [CV] n_neighbors=9, p=1, weights=distance ............................
# [CV]  n_neighbors=9, p=1, weights=distance, score=0.834, total=   0.1s
# [CV] n_neighbors=9, p=1, weights=distance ............................
# [CV]  n_neighbors=9, p=1, weights=distance, score=0.832, total=   0.1s
# [CV] n_neighbors=9, p=1, weights=distance ............................
# [CV]  n_neighbors=9, p=1, weights=distance, score=0.819, total=   0.1s
# [CV] n_neighbors=9, p=1, weights=distance ............................
# [CV]  n_neighbors=9, p=1, weights=distance, score=0.839, total=   0.2s
# [CV] n_neighbors=9, p=2, weights=uniform .............................
# [CV] . n_neighbors=9, p=2, weights=uniform, score=0.833, total=   0.1s
# [CV] n_neighbors=9, p=2, weights=uniform .............................
# [CV] . n_neighbors=9, p=2, weights=uniform, score=0.816, total=   0.1s
# [CV] n_neighbors=9, p=2, weights=uniform .............................
# [CV] . n_neighbors=9, p=2, weights=uniform, score=0.807, total=   0.1s
# [CV] n_neighbors=9, p=2, weights=uniform .............................
# [CV] . n_neighbors=9, p=2, weights=uniform, score=0.800, total=   0.1s
# [CV] n_neighbors=9, p=2, weights=uniform .............................
# [CV] . n_neighbors=9, p=2, weights=uniform, score=0.823, total=   0.1s
# [CV] n_neighbors=9, p=2, weights=distance ............................
# [CV]  n_neighbors=9, p=2, weights=distance, score=0.834, total=   0.1s
# [CV] n_neighbors=9, p=2, weights=distance ............................
# [CV]  n_neighbors=9, p=2, weights=distance, score=0.814, total=   0.1s
# [CV] n_neighbors=9, p=2, weights=distance ............................
# [CV]  n_neighbors=9, p=2, weights=distance, score=0.806, total=   0.1s
# [CV] n_neighbors=9, p=2, weights=distance ............................
# [CV]  n_neighbors=9, p=2, weights=distance, score=0.805, total=   0.1s
# [CV] n_neighbors=9, p=2, weights=distance ............................
# [CV]  n_neighbors=9, p=2, weights=distance, score=0.823, total=   0.1s
# [CV] n_neighbors=11, p=1, weights=uniform ............................
# [CV]  n_neighbors=11, p=1, weights=uniform, score=0.859, total=   0.1s
# [CV] n_neighbors=11, p=1, weights=uniform ............................
# [CV]  n_neighbors=11, p=1, weights=uniform, score=0.835, total=   0.1s
# [CV] n_neighbors=11, p=1, weights=uniform ............................
# [CV]  n_neighbors=11, p=1, weights=uniform, score=0.834, total=   0.1s
# [CV] n_neighbors=11, p=1, weights=uniform ............................
# [CV]  n_neighbors=11, p=1, weights=uniform, score=0.826, total=   0.1s
# [CV] n_neighbors=11, p=1, weights=uniform ............................
# [CV]  n_neighbors=11, p=1, weights=uniform, score=0.848, total=   0.1s
# [CV] n_neighbors=11, p=1, weights=distance ...........................
# [CV]  n_neighbors=11, p=1, weights=distance, score=0.860, total=   0.1s
# [CV] n_neighbors=11, p=1, weights=distance ...........................
# [CV]  n_neighbors=11, p=1, weights=distance, score=0.836, total=   0.1s
# [CV] n_neighbors=11, p=1, weights=distance ...........................
# [CV]  n_neighbors=11, p=1, weights=distance, score=0.830, total=   0.1s
# [CV] n_neighbors=11, p=1, weights=distance ...........................
# [CV]  n_neighbors=11, p=1, weights=distance, score=0.826, total=   0.1s
# [CV] n_neighbors=11, p=1, weights=distance ...........................
# [CV]  n_neighbors=11, p=1, weights=distance, score=0.847, total=   0.1s
# [CV] n_neighbors=11, p=2, weights=uniform ............................
# [CV]  n_neighbors=11, p=2, weights=uniform, score=0.824, total=   0.1s
# [CV] n_neighbors=11, p=2, weights=uniform ............................
# [CV]  n_neighbors=11, p=2, weights=uniform, score=0.819, total=   0.1s
# [CV] n_neighbors=11, p=2, weights=uniform ............................
# [CV]  n_neighbors=11, p=2, weights=uniform, score=0.819, total=   0.1s
# [CV] n_neighbors=11, p=2, weights=uniform ............................
# [CV]  n_neighbors=11, p=2, weights=uniform, score=0.793, total=   0.1s
# [CV] n_neighbors=11, p=2, weights=uniform ............................
# [CV]  n_neighbors=11, p=2, weights=uniform, score=0.816, total=   0.1s
# [CV] n_neighbors=11, p=2, weights=distance ...........................
# [CV]  n_neighbors=11, p=2, weights=distance, score=0.827, total=   0.1s
# [CV] n_neighbors=11, p=2, weights=distance ...........................
# [CV]  n_neighbors=11, p=2, weights=distance, score=0.819, total=   0.1s
# [CV] n_neighbors=11, p=2, weights=distance ...........................
# [CV]  n_neighbors=11, p=2, weights=distance, score=0.819, total=   0.1s
# [CV] n_neighbors=11, p=2, weights=distance ...........................
# [CV]  n_neighbors=11, p=2, weights=distance, score=0.801, total=   0.1s
# [CV] n_neighbors=11, p=2, weights=distance ...........................
# [CV]  n_neighbors=11, p=2, weights=distance, score=0.814, total=   0.1s
# [CV] n_neighbors=15, p=1, weights=uniform ............................
# [CV]  n_neighbors=15, p=1, weights=uniform, score=0.853, total=   0.1s
# [CV] n_neighbors=15, p=1, weights=uniform ............................
# [CV]  n_neighbors=15, p=1, weights=uniform, score=0.841, total=   0.1s
# [CV] n_neighbors=15, p=1, weights=uniform ............................
# [CV]  n_neighbors=15, p=1, weights=uniform, score=0.837, total=   0.1s
# [CV] n_neighbors=15, p=1, weights=uniform ............................
# [CV]  n_neighbors=15, p=1, weights=uniform, score=0.826, total=   0.1s
# [CV] n_neighbors=15, p=1, weights=uniform ............................
# [CV]  n_neighbors=15, p=1, weights=uniform, score=0.842, total=   0.1s
# [CV] n_neighbors=15, p=1, weights=distance ...........................
# [CV]  n_neighbors=15, p=1, weights=distance, score=0.863, total=   0.1s
# [CV] n_neighbors=15, p=1, weights=distance ...........................
# [CV]  n_neighbors=15, p=1, weights=distance, score=0.842, total=   0.1s
# [CV] n_neighbors=15, p=1, weights=distance ...........................
# [CV]  n_neighbors=15, p=1, weights=distance, score=0.837, total=   0.1s
# [CV] n_neighbors=15, p=1, weights=distance ...........................
# [CV]  n_neighbors=15, p=1, weights=distance, score=0.828, total=   0.1s
# [CV] n_neighbors=15, p=1, weights=distance ...........................
# [CV]  n_neighbors=15, p=1, weights=distance, score=0.845, total=   0.1s
# [CV] n_neighbors=15, p=2, weights=uniform ............................
# [CV]  n_neighbors=15, p=2, weights=uniform, score=0.832, total=   0.1s
# [CV] n_neighbors=15, p=2, weights=uniform ............................
# [CV]  n_neighbors=15, p=2, weights=uniform, score=0.811, total=   0.1s
# [CV] n_neighbors=15, p=2, weights=uniform ............................
# [CV]  n_neighbors=15, p=2, weights=uniform, score=0.831, total=   0.1s
# [CV] n_neighbors=15, p=2, weights=uniform ............................
# [CV]  n_neighbors=15, p=2, weights=uniform, score=0.808, total=   0.1s
# [CV] n_neighbors=15, p=2, weights=uniform ............................
# [CV]  n_neighbors=15, p=2, weights=uniform, score=0.813, total=   0.1s
# [CV] n_neighbors=15, p=2, weights=distance ...........................
# [CV]  n_neighbors=15, p=2, weights=distance, score=0.836, total=   0.1s
# [CV] n_neighbors=15, p=2, weights=distance ...........................
# [CV]  n_neighbors=15, p=2, weights=distance, score=0.814, total=   0.1s
# [CV] n_neighbors=15, p=2, weights=distance ...........................
# [CV]  n_neighbors=15, p=2, weights=distance, score=0.830, total=   0.1s
# [CV] n_neighbors=15, p=2, weights=distance ...........................
# [CV]  n_neighbors=15, p=2, weights=distance, score=0.808, total=   0.1s
# [CV] n_neighbors=15, p=2, weights=distance ...........................
# [CV]  n_neighbors=15, p=2, weights=distance, score=0.812, total=   0.1s
# [CV] n_neighbors=17, p=1, weights=uniform ............................
# [CV]  n_neighbors=17, p=1, weights=uniform, score=0.849, total=   0.1s
# [CV] n_neighbors=17, p=1, weights=uniform ............................
# [CV]  n_neighbors=17, p=1, weights=uniform, score=0.844, total=   0.1s
# [CV] n_neighbors=17, p=1, weights=uniform ............................
# [CV]  n_neighbors=17, p=1, weights=uniform, score=0.841, total=   0.1s
# [CV] n_neighbors=17, p=1, weights=uniform ............................
# [CV]  n_neighbors=17, p=1, weights=uniform, score=0.826, total=   0.1s
# [CV] n_neighbors=17, p=1, weights=uniform ............................
# [CV]  n_neighbors=17, p=1, weights=uniform, score=0.841, total=   0.1s
# [CV] n_neighbors=17, p=1, weights=distance ...........................
# [CV]  n_neighbors=17, p=1, weights=distance, score=0.855, total=   0.1s
# [CV] n_neighbors=17, p=1, weights=distance ...........................
# [CV]  n_neighbors=17, p=1, weights=distance, score=0.843, total=   0.1s
# [CV] n_neighbors=17, p=1, weights=distance ...........................
# [CV]  n_neighbors=17, p=1, weights=distance, score=0.836, total=   0.1s
# [CV] n_neighbors=17, p=1, weights=distance ...........................
# [CV]  n_neighbors=17, p=1, weights=distance, score=0.829, total=   0.1s
# [CV] n_neighbors=17, p=1, weights=distance ...........................
# [CV]  n_neighbors=17, p=1, weights=distance, score=0.840, total=   0.1s
# [CV] n_neighbors=17, p=2, weights=uniform ............................
# [CV]  n_neighbors=17, p=2, weights=uniform, score=0.838, total=   0.1s
# [CV] n_neighbors=17, p=2, weights=uniform ............................
# [CV]  n_neighbors=17, p=2, weights=uniform, score=0.811, total=   0.1s
# [CV] n_neighbors=17, p=2, weights=uniform ............................
# [CV]  n_neighbors=17, p=2, weights=uniform, score=0.830, total=   0.1s
# [CV] n_neighbors=17, p=2, weights=uniform ............................
# [CV]  n_neighbors=17, p=2, weights=uniform, score=0.803, total=   0.1s
# [CV] n_neighbors=17, p=2, weights=uniform ............................
# [CV]  n_neighbors=17, p=2, weights=uniform, score=0.813, total=   0.1s
# [CV] n_neighbors=17, p=2, weights=distance ...........................
# [CV]  n_neighbors=17, p=2, weights=distance, score=0.838, total=   0.1s
# [CV] n_neighbors=17, p=2, weights=distance ...........................
# [CV]  n_neighbors=17, p=2, weights=distance, score=0.810, total=   0.1s
# [CV] n_neighbors=17, p=2, weights=distance ...........................
# [CV]  n_neighbors=17, p=2, weights=distance, score=0.829, total=   0.1s
# [CV] n_neighbors=17, p=2, weights=distance ...........................
# [CV]  n_neighbors=17, p=2, weights=distance, score=0.806, total=   0.1s
# [CV] n_neighbors=17, p=2, weights=distance ...........................
# [CV]  n_neighbors=17, p=2, weights=distance, score=0.813, total=   0.1s
# [CV] n_neighbors=19, p=1, weights=uniform ............................
# [CV]  n_neighbors=19, p=1, weights=uniform, score=0.855, total=   0.2s
# [CV] n_neighbors=19, p=1, weights=uniform ............................
# [CV]  n_neighbors=19, p=1, weights=uniform, score=0.837, total=   0.1s
# [CV] n_neighbors=19, p=1, weights=uniform ............................
# [CV]  n_neighbors=19, p=1, weights=uniform, score=0.839, total=   0.1s
# [CV] n_neighbors=19, p=1, weights=uniform ............................
# [CV]  n_neighbors=19, p=1, weights=uniform, score=0.830, total=   0.1s
# [CV] n_neighbors=19, p=1, weights=uniform ............................
# [CV]  n_neighbors=19, p=1, weights=uniform, score=0.838, total=   0.1s
# [CV] n_neighbors=19, p=1, weights=distance ...........................
# [CV]  n_neighbors=19, p=1, weights=distance, score=0.859, total=   0.1s
# [CV] n_neighbors=19, p=1, weights=distance ...........................
# [CV]  n_neighbors=19, p=1, weights=distance, score=0.839, total=   0.1s
# [CV] n_neighbors=19, p=1, weights=distance ...........................
# [CV]  n_neighbors=19, p=1, weights=distance, score=0.838, total=   0.1s
# [CV] n_neighbors=19, p=1, weights=distance ...........................
# [CV]  n_neighbors=19, p=1, weights=distance, score=0.833, total=   0.1s
# [CV] n_neighbors=19, p=1, weights=distance ...........................
# [CV]  n_neighbors=19, p=1, weights=distance, score=0.839, total=   0.1s
# [CV] n_neighbors=19, p=2, weights=uniform ............................
# [CV]  n_neighbors=19, p=2, weights=uniform, score=0.834, total=   0.1s
# [CV] n_neighbors=19, p=2, weights=uniform ............................
# [CV]  n_neighbors=19, p=2, weights=uniform, score=0.810, total=   0.1s
# [CV] n_neighbors=19, p=2, weights=uniform ............................
# [CV]  n_neighbors=19, p=2, weights=uniform, score=0.837, total=   0.1s
# [CV] n_neighbors=19, p=2, weights=uniform ............................
# [CV]  n_neighbors=19, p=2, weights=uniform, score=0.805, total=   0.1s
# [CV] n_neighbors=19, p=2, weights=uniform ............................
# [CV]  n_neighbors=19, p=2, weights=uniform, score=0.820, total=   0.1s
# [CV] n_neighbors=19, p=2, weights=distance ...........................
# [CV]  n_neighbors=19, p=2, weights=distance, score=0.835, total=   0.1s
# [CV] n_neighbors=19, p=2, weights=distance ...........................
# [CV]  n_neighbors=19, p=2, weights=distance, score=0.815, total=   0.1s
# [CV] n_neighbors=19, p=2, weights=distance ...........................
# [CV]  n_neighbors=19, p=2, weights=distance, score=0.835, total=   0.1s
# [CV] n_neighbors=19, p=2, weights=distance ...........................
# [CV]  n_neighbors=19, p=2, weights=distance, score=0.807, total=   0.1s
# [CV] n_neighbors=19, p=2, weights=distance ...........................
# [CV]  n_neighbors=19, p=2, weights=distance, score=0.821, total=   0.1s
# [CV] n_neighbors=21, p=1, weights=uniform ............................
# [CV]  n_neighbors=21, p=1, weights=uniform, score=0.855, total=   0.2s
# [CV] n_neighbors=21, p=1, weights=uniform ............................
# [CV]  n_neighbors=21, p=1, weights=uniform, score=0.841, total=   0.2s
# [CV] n_neighbors=21, p=1, weights=uniform ............................
# [CV]  n_neighbors=21, p=1, weights=uniform, score=0.841, total=   0.2s
# [CV] n_neighbors=21, p=1, weights=uniform ............................
# [CV]  n_neighbors=21, p=1, weights=uniform, score=0.828, total=   0.2s
# [CV] n_neighbors=21, p=1, weights=uniform ............................
# [CV]  n_neighbors=21, p=1, weights=uniform, score=0.839, total=   0.1s
# [CV] n_neighbors=21, p=1, weights=distance ...........................
# [CV]  n_neighbors=21, p=1, weights=distance, score=0.857, total=   0.2s
# [CV] n_neighbors=21, p=1, weights=distance ...........................
# [CV]  n_neighbors=21, p=1, weights=distance, score=0.840, total=   0.1s
# [CV] n_neighbors=21, p=1, weights=distance ...........................
# [CV]  n_neighbors=21, p=1, weights=distance, score=0.839, total=   0.1s
# [CV] n_neighbors=21, p=1, weights=distance ...........................
# [CV]  n_neighbors=21, p=1, weights=distance, score=0.830, total=   0.1s
# [CV] n_neighbors=21, p=1, weights=distance ...........................
# [CV]  n_neighbors=21, p=1, weights=distance, score=0.844, total=   0.1s
# [CV] n_neighbors=21, p=2, weights=uniform ............................
# [CV]  n_neighbors=21, p=2, weights=uniform, score=0.829, total=   0.1s
# [CV] n_neighbors=21, p=2, weights=uniform ............................
# [CV]  n_neighbors=21, p=2, weights=uniform, score=0.812, total=   0.1s
# [CV] n_neighbors=21, p=2, weights=uniform ............................
# [CV]  n_neighbors=21, p=2, weights=uniform, score=0.838, total=   0.1s
# [CV] n_neighbors=21, p=2, weights=uniform ............................
# [CV]  n_neighbors=21, p=2, weights=uniform, score=0.810, total=   0.1s
# [CV] n_neighbors=21, p=2, weights=uniform ............................
# [CV]  n_neighbors=21, p=2, weights=uniform, score=0.822, total=   0.1s
# [CV] n_neighbors=21, p=2, weights=distance ...........................
# [CV]  n_neighbors=21, p=2, weights=distance, score=0.834, total=   0.1s
# [CV] n_neighbors=21, p=2, weights=distance ...........................
# [CV]  n_neighbors=21, p=2, weights=distance, score=0.814, total=   0.1s
# [CV] n_neighbors=21, p=2, weights=distance ...........................
# [CV]  n_neighbors=21, p=2, weights=distance, score=0.839, total=   0.1s
# [CV] n_neighbors=21, p=2, weights=distance ...........................
# [CV]  n_neighbors=21, p=2, weights=distance, score=0.805, total=   0.1s
# [CV] n_neighbors=21, p=2, weights=distance ...........................
# [CV]  n_neighbors=21, p=2, weights=distance, score=0.822, total=   0.1s
# [CV] n_neighbors=23, p=1, weights=uniform ............................
# [CV]  n_neighbors=23, p=1, weights=uniform, score=0.855, total=   0.2s
# [CV] n_neighbors=23, p=1, weights=uniform ............................
# [CV]  n_neighbors=23, p=1, weights=uniform, score=0.838, total=   0.2s
# [CV] n_neighbors=23, p=1, weights=uniform ............................
# [CV]  n_neighbors=23, p=1, weights=uniform, score=0.840, total=   0.2s
# [CV] n_neighbors=23, p=1, weights=uniform ............................
# [CV]  n_neighbors=23, p=1, weights=uniform, score=0.828, total=   0.1s
# [CV] n_neighbors=23, p=1, weights=uniform ............................
# [CV]  n_neighbors=23, p=1, weights=uniform, score=0.838, total=   0.1s
# [CV] n_neighbors=23, p=1, weights=distance ...........................
# [CV]  n_neighbors=23, p=1, weights=distance, score=0.855, total=   0.2s
# [CV] n_neighbors=23, p=1, weights=distance ...........................
# [CV]  n_neighbors=23, p=1, weights=distance, score=0.839, total=   0.1s
# [CV] n_neighbors=23, p=1, weights=distance ...........................
# [CV]  n_neighbors=23, p=1, weights=distance, score=0.841, total=   0.2s
# [CV] n_neighbors=23, p=1, weights=distance ...........................
# [CV]  n_neighbors=23, p=1, weights=distance, score=0.830, total=   0.1s
# [CV] n_neighbors=23, p=1, weights=distance ...........................
# [CV]  n_neighbors=23, p=1, weights=distance, score=0.840, total=   0.1s
# [CV] n_neighbors=23, p=2, weights=uniform ............................
# [CV]  n_neighbors=23, p=2, weights=uniform, score=0.830, total=   0.2s
# [CV] n_neighbors=23, p=2, weights=uniform ............................
# [CV]  n_neighbors=23, p=2, weights=uniform, score=0.811, total=   0.1s
# [CV] n_neighbors=23, p=2, weights=uniform ............................
# [CV]  n_neighbors=23, p=2, weights=uniform, score=0.833, total=   0.2s
# [CV] n_neighbors=23, p=2, weights=uniform ............................
# [CV]  n_neighbors=23, p=2, weights=uniform, score=0.810, total=   0.1s
# [CV] n_neighbors=23, p=2, weights=uniform ............................
# [CV]  n_neighbors=23, p=2, weights=uniform, score=0.818, total=   0.1s
# [CV] n_neighbors=23, p=2, weights=distance ...........................
# [CV]  n_neighbors=23, p=2, weights=distance, score=0.834, total=   0.1s
# [CV] n_neighbors=23, p=2, weights=distance ...........................
# [CV]  n_neighbors=23, p=2, weights=distance, score=0.817, total=   0.1s
# [CV] n_neighbors=23, p=2, weights=distance ...........................
# [CV]  n_neighbors=23, p=2, weights=distance, score=0.832, total=   0.1s
# [CV] n_neighbors=23, p=2, weights=distance ...........................
# [CV]  n_neighbors=23, p=2, weights=distance, score=0.805, total=   0.1s
# [CV] n_neighbors=23, p=2, weights=distance ...........................
# [CV]  n_neighbors=23, p=2, weights=distance, score=0.818, total=   0.1s
# [CV] n_neighbors=25, p=1, weights=uniform ............................
# [CV]  n_neighbors=25, p=1, weights=uniform, score=0.856, total=   0.2s
# [CV] n_neighbors=25, p=1, weights=uniform ............................
# [CV]  n_neighbors=25, p=1, weights=uniform, score=0.837, total=   0.2s
# [CV] n_neighbors=25, p=1, weights=uniform ............................
# [CV]  n_neighbors=25, p=1, weights=uniform, score=0.846, total=   0.2s
# [CV] n_neighbors=25, p=1, weights=uniform ............................
# [CV]  n_neighbors=25, p=1, weights=uniform, score=0.829, total=   0.2s
# [CV] n_neighbors=25, p=1, weights=uniform ............................
# [CV]  n_neighbors=25, p=1, weights=uniform, score=0.843, total=   0.1s
# [CV] n_neighbors=25, p=1, weights=distance ...........................
# [CV]  n_neighbors=25, p=1, weights=distance, score=0.860, total=   0.1s
# [CV] n_neighbors=25, p=1, weights=distance ...........................
# [CV]  n_neighbors=25, p=1, weights=distance, score=0.836, total=   0.1s
# [CV] n_neighbors=25, p=1, weights=distance ...........................
# [CV]  n_neighbors=25, p=1, weights=distance, score=0.846, total=   0.1s
# [CV] n_neighbors=25, p=1, weights=distance ...........................
# [CV]  n_neighbors=25, p=1, weights=distance, score=0.831, total=   0.1s
# [CV] n_neighbors=25, p=1, weights=distance ...........................
# [CV]  n_neighbors=25, p=1, weights=distance, score=0.842, total=   0.1s
# [CV] n_neighbors=25, p=2, weights=uniform ............................
# [CV]  n_neighbors=25, p=2, weights=uniform, score=0.832, total=   0.1s
# [CV] n_neighbors=25, p=2, weights=uniform ............................
# [CV]  n_neighbors=25, p=2, weights=uniform, score=0.817, total=   0.2s
# [CV] n_neighbors=25, p=2, weights=uniform ............................
# [CV]  n_neighbors=25, p=2, weights=uniform, score=0.836, total=   0.1s
# [CV] n_neighbors=25, p=2, weights=uniform ............................
# [CV]  n_neighbors=25, p=2, weights=uniform, score=0.803, total=   0.1s
# [CV] n_neighbors=25, p=2, weights=uniform ............................
# [CV]  n_neighbors=25, p=2, weights=uniform, score=0.818, total=   0.1s
# [CV] n_neighbors=25, p=2, weights=distance ...........................
# [CV]  n_neighbors=25, p=2, weights=distance, score=0.835, total=   0.1s
# [CV] n_neighbors=25, p=2, weights=distance ...........................
# [CV]  n_neighbors=25, p=2, weights=distance, score=0.816, total=   0.1s
# [CV] n_neighbors=25, p=2, weights=distance ...........................
# [CV]  n_neighbors=25, p=2, weights=distance, score=0.836, total=   0.1s
# [CV] n_neighbors=25, p=2, weights=distance ...........................
# [CV]  n_neighbors=25, p=2, weights=distance, score=0.806, total=   0.1s
# [CV] n_neighbors=25, p=2, weights=distance ...........................
# [CV]  n_neighbors=25, p=2, weights=distance, score=0.818, total=   0.1s
# [CV] n_neighbors=27, p=1, weights=uniform ............................
# [CV]  n_neighbors=27, p=1, weights=uniform, score=0.858, total=   0.2s
# [CV] n_neighbors=27, p=1, weights=uniform ............................
# [CV]  n_neighbors=27, p=1, weights=uniform, score=0.841, total=   0.2s
# [CV] n_neighbors=27, p=1, weights=uniform ............................
# [CV]  n_neighbors=27, p=1, weights=uniform, score=0.848, total=   0.2s
# [CV] n_neighbors=27, p=1, weights=uniform ............................
# [CV]  n_neighbors=27, p=1, weights=uniform, score=0.826, total=   0.2s
# [CV] n_neighbors=27, p=1, weights=uniform ............................
# [CV]  n_neighbors=27, p=1, weights=uniform, score=0.841, total=   0.2s
# [CV] n_neighbors=27, p=1, weights=distance ...........................
# [CV]  n_neighbors=27, p=1, weights=distance, score=0.861, total=   0.1s
# [CV] n_neighbors=27, p=1, weights=distance ...........................
# [CV]  n_neighbors=27, p=1, weights=distance, score=0.839, total=   0.2s
# [CV] n_neighbors=27, p=1, weights=distance ...........................
# [CV]  n_neighbors=27, p=1, weights=distance, score=0.846, total=   0.1s
# [CV] n_neighbors=27, p=1, weights=distance ...........................
# [CV]  n_neighbors=27, p=1, weights=distance, score=0.829, total=   0.2s
# [CV] n_neighbors=27, p=1, weights=distance ...........................
# [CV]  n_neighbors=27, p=1, weights=distance, score=0.840, total=   0.1s
# [CV] n_neighbors=27, p=2, weights=uniform ............................
# [CV]  n_neighbors=27, p=2, weights=uniform, score=0.828, total=   0.1s
# [CV] n_neighbors=27, p=2, weights=uniform ............................
# [CV]  n_neighbors=27, p=2, weights=uniform, score=0.821, total=   0.1s
# [CV] n_neighbors=27, p=2, weights=uniform ............................
# [CV]  n_neighbors=27, p=2, weights=uniform, score=0.834, total=   0.1s
# [CV] n_neighbors=27, p=2, weights=uniform ............................
# [CV]  n_neighbors=27, p=2, weights=uniform, score=0.800, total=   0.1s
# [CV] n_neighbors=27, p=2, weights=uniform ............................
# [CV]  n_neighbors=27, p=2, weights=uniform, score=0.822, total=   0.1s
# [CV] n_neighbors=27, p=2, weights=distance ...........................
# [CV]  n_neighbors=27, p=2, weights=distance, score=0.832, total=   0.1s
# [CV] n_neighbors=27, p=2, weights=distance ...........................
# [CV]  n_neighbors=27, p=2, weights=distance, score=0.820, total=   0.1s
# [CV] n_neighbors=27, p=2, weights=distance ...........................
# [CV]  n_neighbors=27, p=2, weights=distance, score=0.838, total=   0.1s
# [CV] n_neighbors=27, p=2, weights=distance ...........................
# [CV]  n_neighbors=27, p=2, weights=distance, score=0.804, total=   0.1s
# [CV] n_neighbors=27, p=2, weights=distance ...........................
# [CV]  n_neighbors=27, p=2, weights=distance, score=0.822, total=   0.1s
# [CV] n_neighbors=29, p=1, weights=uniform ............................
# [CV]  n_neighbors=29, p=1, weights=uniform, score=0.856, total=   0.2s
# [CV] n_neighbors=29, p=1, weights=uniform ............................
# [CV]  n_neighbors=29, p=1, weights=uniform, score=0.837, total=   0.2s
# [CV] n_neighbors=29, p=1, weights=uniform ............................
# [CV]  n_neighbors=29, p=1, weights=uniform, score=0.851, total=   0.2s
# [CV] n_neighbors=29, p=1, weights=uniform ............................
# [CV]  n_neighbors=29, p=1, weights=uniform, score=0.828, total=   0.2s
# [CV] n_neighbors=29, p=1, weights=uniform ............................
# [CV]  n_neighbors=29, p=1, weights=uniform, score=0.842, total=   0.2s
# [CV] n_neighbors=29, p=1, weights=distance ...........................
# [CV]  n_neighbors=29, p=1, weights=distance, score=0.861, total=   0.2s
# [CV] n_neighbors=29, p=1, weights=distance ...........................
# [CV]  n_neighbors=29, p=1, weights=distance, score=0.840, total=   0.2s
# [CV] n_neighbors=29, p=1, weights=distance ...........................
# [CV]  n_neighbors=29, p=1, weights=distance, score=0.849, total=   0.1s
# [CV] n_neighbors=29, p=1, weights=distance ...........................
# [CV]  n_neighbors=29, p=1, weights=distance, score=0.830, total=   0.1s
# [CV] n_neighbors=29, p=1, weights=distance ...........................
# [CV]  n_neighbors=29, p=1, weights=distance, score=0.843, total=   0.2s
# [CV] n_neighbors=29, p=2, weights=uniform ............................
# [CV]  n_neighbors=29, p=2, weights=uniform, score=0.827, total=   0.2s
# [CV] n_neighbors=29, p=2, weights=uniform ............................
# [CV]  n_neighbors=29, p=2, weights=uniform, score=0.820, total=   0.1s
# [CV] n_neighbors=29, p=2, weights=uniform ............................
# [CV]  n_neighbors=29, p=2, weights=uniform, score=0.833, total=   0.2s
# [CV] n_neighbors=29, p=2, weights=uniform ............................
# [CV]  n_neighbors=29, p=2, weights=uniform, score=0.803, total=   0.1s
# [CV] n_neighbors=29, p=2, weights=uniform ............................
# [CV]  n_neighbors=29, p=2, weights=uniform, score=0.818, total=   0.1s
# [CV] n_neighbors=29, p=2, weights=distance ...........................
# [CV]  n_neighbors=29, p=2, weights=distance, score=0.831, total=   0.1s
# [CV] n_neighbors=29, p=2, weights=distance ...........................
# [CV]  n_neighbors=29, p=2, weights=distance, score=0.818, total=   0.1s
# [CV] n_neighbors=29, p=2, weights=distance ...........................
# [CV]  n_neighbors=29, p=2, weights=distance, score=0.834, total=   0.1s
# [CV] n_neighbors=29, p=2, weights=distance ...........................
# [CV]  n_neighbors=29, p=2, weights=distance, score=0.809, total=   0.1s
# [CV] n_neighbors=29, p=2, weights=distance ...........................
# [CV]  n_neighbors=29, p=2, weights=distance, score=0.816, total=   0.1s
# [Parallel(n_jobs=1)]: Done 220 out of 220 | elapsed:   29.4s finished
# GridSearchCV(estimator=KNeighborsClassifier(n_neighbors=19),
#              param_grid={'n_neighbors': [7, 9, 11, 15, 17, 19, 21, 23, 25, 27,
#                                          29],
#                          'p': [1, 2], 'weights': ['uniform', 'distance']},
#              verbose=3)

# %%
print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'n_neighbors': 29, 'p': 1, 'weights': 'distance'}
# 0.8445515176212897

# %% [markdown]
# # Save the Model

# %%
# save your model by updating "your_name" with your name
# and "your_model" with your model variable
# be sure to turn this in to BCS
# if joblib fails to import, try running the command to install in terminal/git-bash
import joblib
filename = 'Models/model_knn.sav'
joblib.dump(model_knn, filename)
# Out:
# ['Models/model_knn.sav']
