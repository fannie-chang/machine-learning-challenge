# %%
# Update sklearn to prevent version mismatches
# !pip install sklearn --upgrade
# Out:
# Requirement already satisfied: sklearn in /opt/anaconda3/lib/python3.8/site-packages (0.0)
# Requirement already satisfied: scikit-learn in /opt/anaconda3/lib/python3.8/site-packages (from sklearn) (0.23.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/anaconda3/lib/python3.8/site-packages (from scikit-learn->sklearn) (2.2.0)
# Requirement already satisfied: scipy>=0.19.1 in /opt/anaconda3/lib/python3.8/site-packages (from scikit-learn->sklearn) (1.6.2)
# Requirement already satisfied: numpy>=1.13.3 in /opt/anaconda3/lib/python3.8/site-packages (from scikit-learn->sklearn) (1.19.5)
# Requirement already satisfied: joblib>=0.11 in /opt/anaconda3/lib/python3.8/site-packages (from scikit-learn->sklearn) (1.0.1)

# %%
# install joblib. This will be used to save your model. 
# Restart your kernel after installing 
# !pip install joblib
# Out:
# Requirement already satisfied: joblib in /opt/anaconda3/lib/python3.8/site-packages (1.0.1)

# %%
from sklearn import tree
import pandas as pd
import os

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("Resources/exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %% [markdown]
# # Select your features (columns)

# %%
# Set features. This will also be used as your x values.
target = df["koi_disposition"]
target_names = ["negative" , "positive"]

# %%
data = df.drop("koi_disposition", axis =1)
feature_names = data.columns
data.head()
# Out:
#    koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 0              0              0              0              0   54.418383
# 1              0              1              0              0   19.899140
# 2              0              1              0              0    1.736952
# 3              0              0              0              0    2.525592
# 4              0              0              0              0    4.134435
#
#    koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 0     2.479000e-04    -2.479000e-04   162.513840          0.003520
# 1     1.490000e-05    -1.490000e-05   175.850252          0.000581
# 2     2.630000e-07    -2.630000e-07   170.307565          0.000115
# 3     3.760000e-06    -3.760000e-06   171.595550          0.001130
# 4     1.050000e-05    -1.050000e-05   172.979370          0.001900
#
#    koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0         -0.003520  ...             -81      4.467           0.064
# 1         -0.000581  ...            -176      4.544           0.044
# 2         -0.000115  ...            -174      4.564           0.053
# 3         -0.001130  ...            -211      4.438           0.070
# 4         -0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 40 columns]

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
# Split the data using train_test_split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=42)

# %%
X_train.head()
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 6122              0              0              0              0    6.768901
# 6370              0              1              0              1    0.733726
# 2879              1              0              0              0    7.652707
# 107               0              0              0              0    7.953547
# 29                0              0              0              0    4.959319
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 6122     7.380000e-05    -7.380000e-05   133.077240          0.008440
# 6370     6.060000e-06    -6.060000e-06   132.020050          0.007950
# 2879     6.540000e-05    -6.540000e-05   134.460380          0.006190
# 107      1.910000e-05    -1.910000e-05   174.662240          0.001820
# 29       5.150000e-07    -5.150000e-07   172.258529          0.000083
#
#       koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 6122         -0.008440  ...            -171      4.327           0.153
# 6370         -0.007950  ...            -175      4.578           0.033
# 2879         -0.006190  ...            -189      4.481           0.050
# 107          -0.001820  ...             -85      4.536           0.056
# 29           -0.000083  ...             -77      4.359           0.110
#
#       koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 6122          -0.187     1.125          0.310         -0.207  294.40472
# 6370          -0.187     0.797          0.211         -0.056  284.50391
# 2879          -0.200     0.963          0.290         -0.097  295.50211
# 107           -0.016     0.779          0.023         -0.049  291.15878
# 29            -0.110     1.082          0.173         -0.130  292.16705
#
#             dec  koi_kepmag
# 6122  39.351681      14.725
# 6370  42.463860      15.770
# 2879  38.983540      13.099
# 107   40.750271      15.660
# 29    48.727589      15.263
#
# [5 rows x 40 columns]

# %%
# Create a Decision Tree Classifier
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)

# %%
data.describe()
# Out:
#        koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# count    6991.000000    6991.000000    6991.000000    6991.000000
# mean        0.157059       0.244743       0.202975       0.125018
# std         0.363882       0.429966       0.402243       0.330763
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000       0.000000
# max         1.000000       1.000000       1.000000       1.000000
#
#         koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# count  6991.000000     6.991000e+03     6.991000e+03  6991.000000
# mean     56.191248     1.851122e-03    -1.851122e-03   164.488820
# std     117.570962     7.184503e-03     7.184503e-03    67.020475
# min       0.259820     1.100000e-08    -1.568000e-01   120.515914
# 25%       2.620126     5.005000e-06    -2.401000e-04   132.683917
# 50%       8.947426     3.300000e-05    -3.300000e-05   136.739230
# 75%      34.282605     2.401000e-04    -5.005000e-06   169.937005
# max    1071.232624     1.568000e-01    -1.100000e-08  1472.522306
#
#        koi_time0bk_err1  koi_time0bk_err2  ...  koi_steff_err2    koi_slogg  \
# count       6991.000000       6991.000000  ...     6991.000000  6991.000000
# mean           0.009340         -0.009340  ...     -161.206980     4.305049
# std            0.021989          0.021989  ...       71.448481     0.439238
# min            0.000009         -0.569000  ...    -1733.000000     0.047000
# 25%            0.001145         -0.010000  ...     -197.000000     4.209000
# 50%            0.003990         -0.003990  ...     -159.000000     4.436000
# 75%            0.010000         -0.001145  ...     -112.000000     4.543000
# max            0.569000         -0.000009  ...        0.000000     5.364000
#
#        koi_slogg_err1  koi_slogg_err2     koi_srad  koi_srad_err1  \
# count     6991.000000      6991.00000  6991.000000    6991.000000
# mean         0.121091        -0.14048     1.740749       0.352710
# std          0.132048         0.08199     5.903415       0.839017
# min          0.000000        -1.00700     0.109000       0.000000
# 25%          0.044000        -0.19500     0.829000       0.128000
# 50%          0.070000        -0.12700     0.999000       0.248000
# 75%          0.149000        -0.08800     1.357000       0.357000
# max          1.472000         0.00000   180.013000      25.956000
#
#        koi_srad_err2           ra          dec   koi_kepmag
# count    6991.000000  6991.000000  6991.000000  6991.000000
# mean       -0.388568   292.082406    43.812143    14.271508
# std         1.907797     4.762908     3.606167     1.350802
# min      -103.825000   279.856080    36.577381     6.966000
# 25%        -0.252000   288.704730    40.797760    13.455000
# 50%        -0.111000   292.314760    43.679661    14.534000
# 75%        -0.069000   295.888550    46.693659    15.322000
# max         0.000000   301.720760    52.336010    19.065000
#
# [8 rows x 40 columns]

# %%
clf.score(X_test, y_test)
# Out:
# 0.8432494279176201

# %%
# Fit the classifier to the data
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=200)
rf = rf.fit(X_train, y_train)
# 0.729167

# %%
rf.score(X_test, y_test)
# Out:
# 0.8998855835240275

# %%
features_data=sorted(zip(rf.feature_importances_, feature_names), reverse=True)

# %%
 features_data
# Out:
# [(0.10302616234264474, 'koi_fpflag_co'),
#  (0.10285816543681475, 'koi_fpflag_nt'),
#  (0.07102747968771927, 'koi_fpflag_ss'),
#  (0.05543272025317121, 'koi_model_snr'),
#  (0.043473806424630876, 'koi_prad'),
#  (0.036737116211899706, 'koi_duration_err1'),
#  (0.03330703486650935, 'koi_steff_err1'),
#  (0.03238812774167004, 'koi_fpflag_ec'),
#  (0.03232317403594832, 'koi_duration_err2'),
#  (0.030376263862039097, 'koi_prad_err2'),
#  (0.030139684987393528, 'koi_prad_err1'),
#  (0.02801401689980022, 'koi_steff_err2'),
#  (0.023097922715847968, 'koi_period'),
#  (0.022169342736265724, 'koi_duration'),
#  (0.022119475800461804, 'koi_time0bk_err2'),
#  (0.021719091763947772, 'koi_depth'),
#  (0.020820671833089836, 'koi_time0bk_err1'),
#  (0.019794025848119588, 'koi_impact'),
#  (0.018747293393737582, 'koi_period_err2'),
#  (0.018499686241235484, 'koi_insol_err1'),
#  (0.01813387168173789, 'koi_period_err1'),
#  (0.017000548799375056, 'koi_insol'),
#  (0.016180259928194097, 'koi_teq'),
#  (0.01594120863102529, 'koi_insol_err2'),
#  (0.013577079859226217, 'koi_depth_err2'),
#  (0.013490117376311138, 'koi_depth_err1'),
#  (0.012739188997306496, 'koi_time0bk'),
#  (0.012208811725963536, 'koi_srad_err1'),
#  (0.01210752925237702, 'ra'),
#  (0.011899080959351032, 'koi_impact_err2'),
#  (0.011522885314311393, 'dec'),
#  (0.01106956707527889, 'koi_impact_err1'),
#  (0.010224131668037942, 'koi_slogg_err2'),
#  (0.010180047755712036, 'koi_steff'),
#  (0.010147923907617819, 'koi_kepmag'),
#  (0.009259318292792392, 'koi_slogg'),
#  (0.008926526893299752, 'koi_srad'),
#  (0.008463519098151477, 'koi_slogg_err1'),
#  (0.008153530147367208, 'koi_srad_err2'),
#  (0.002703589553616458, 'koi_tce_plnt_num')]

# %%
[x[0] for x in features_data]
# Out:
# [0.10302616234264474,
#  0.10285816543681475,
#  0.07102747968771927,
#  0.05543272025317121,
#  0.043473806424630876,
#  0.036737116211899706,
#  0.03330703486650935,
#  0.03238812774167004,
#  0.03232317403594832,
#  0.030376263862039097,
#  0.030139684987393528,
#  0.02801401689980022,
#  0.023097922715847968,
#  0.022169342736265724,
#  0.022119475800461804,
#  0.021719091763947772,
#  0.020820671833089836,
#  0.019794025848119588,
#  0.018747293393737582,
#  0.018499686241235484,
#  0.01813387168173789,
#  0.017000548799375056,
#  0.016180259928194097,
#  0.01594120863102529,
#  0.013577079859226217,
#  0.013490117376311138,
#  0.012739188997306496,
#  0.012208811725963536,
#  0.01210752925237702,
#  0.011899080959351032,
#  0.011522885314311393,
#  0.01106956707527889,
#  0.010224131668037942,
#  0.010180047755712036,
#  0.010147923907617819,
#  0.009259318292792392,
#  0.008926526893299752,
#  0.008463519098151477,
#  0.008153530147367208,
#  0.002703589553616458]

# %%
np.sum([x[0] for x in features_data])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-a8c0a5ac032c> in <module>
# ----> 1 np.sum([x[0] for x in features_data])
#
# NameError: name 'np' is not defined

# %%
X_train.iloc[:,1:]
# Out:
#       koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 6122              0              0              0    6.768901
# 6370              1              0              1    0.733726
# 2879              0              0              0    7.652707
# 107               0              0              0    7.953547
# 29                0              0              0    4.959319
# ...             ...            ...            ...         ...
# 3772              1              0              0    8.268081
# 5191              0              0              0   11.161938
# 5226              1              0              0    6.150251
# 5390              0              0              0    3.343285
# 860               0              1              0    2.271907
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 6122     7.380000e-05    -7.380000e-05   133.077240          0.008440
# 6370     6.060000e-06    -6.060000e-06   132.020050          0.007950
# 2879     6.540000e-05    -6.540000e-05   134.460380          0.006190
# 107      1.910000e-05    -1.910000e-05   174.662240          0.001820
# 29       5.150000e-07    -5.150000e-07   172.258529          0.000083
# ...               ...              ...          ...               ...
# 3772     6.340000e-07    -6.340000e-07   135.056330          0.000064
# 5191     1.677000e-04    -1.677000e-04   133.553800          0.013000
# 5226     7.000000e-07    -7.000000e-07   134.422825          0.000088
# 5390     4.380000e-05    -4.380000e-05   134.845100          0.011200
# 860      1.300000e-05    -1.300000e-05   134.798520          0.004670
#
#       koi_time0bk_err2  koi_impact  ...  koi_steff_err2  koi_slogg  \
# 6122         -0.008440       0.150  ...            -171      4.327
# 6370         -0.007950       0.291  ...            -175      4.578
# 2879         -0.006190       0.970  ...            -189      4.481
# 107          -0.001820       0.300  ...             -85      4.536
# 29           -0.000083       0.831  ...             -77      4.359
# ...                ...         ...  ...             ...        ...
# 3772         -0.000064       1.099  ...            -190      4.502
# 5191         -0.013000       0.739  ...            -124      4.072
# 5226         -0.000088       1.270  ...            -458      3.896
# 5390         -0.011200       1.210  ...            -197      3.773
# 860          -0.004670       0.719  ...            -155      4.506
#
#       koi_slogg_err1  koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2  \
# 6122           0.153          -0.187     1.125          0.310         -0.207
# 6370           0.033          -0.187     0.797          0.211         -0.056
# 2879           0.050          -0.200     0.963          0.290         -0.097
# 107            0.056          -0.016     0.779          0.023         -0.049
# 29             0.110          -0.110     1.082          0.173         -0.130
# ...              ...             ...       ...            ...            ...
# 3772           0.050          -0.200     0.922          0.273         -0.091
# 5191           0.188          -0.101     1.640          0.281         -0.343
# 5226           0.270          -0.180     2.867          0.988         -1.087
# 5390           0.293          -0.098     2.652          0.433         -0.939
# 860            0.072          -0.168     0.856          0.225         -0.096
#
#              ra        dec  koi_kepmag
# 6122  294.40472  39.351681      14.725
# 6370  284.50391  42.463860      15.770
# 2879  295.50211  38.983540      13.099
# 107   291.15878  40.750271      15.660
# 29    292.16705  48.727589      15.263
# ...         ...        ...         ...
# 3772  292.53125  46.728699      15.768
# 5191  295.21268  49.562180      13.374
# 5226  297.18176  45.988441      10.622
# 5390  296.86258  41.147419      13.276
# 860   294.73419  40.861420      14.459
#
# [5243 rows x 39 columns]

# %%
# from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=200)
rf = rf.fit(X_train.iloc[:,1:], y_train)

# %%
rf.score(X_test.iloc[:,1:], y_test)
# Out:
# 0.8495423340961098

# %%
feature_names = data.iloc[:,1:].columns

# %%
features_data=sorted(zip(rf.feature_importances_, feature_names), reverse=True)

# %%
features_data
# Out:
# [(0.10344017465445904, 'koi_fpflag_co'),
#  (0.060196545036592594, 'koi_fpflag_ss'),
#  (0.05977887712185082, 'koi_model_snr'),
#  (0.05225463360393756, 'koi_prad'),
#  (0.040066996274379915, 'koi_duration_err1'),
#  (0.038810540229084416, 'koi_duration_err2'),
#  (0.03574270854346386, 'koi_steff_err1'),
#  (0.034836675292299404, 'koi_fpflag_ec'),
#  (0.03372038590059782, 'koi_prad_err2'),
#  (0.03080390089757596, 'koi_steff_err2'),
#  (0.030515533146731534, 'koi_prad_err1'),
#  (0.02987490723451296, 'koi_period'),
#  (0.026732029426637435, 'koi_depth'),
#  (0.026335595291524964, 'koi_duration'),
#  (0.024582231328786282, 'koi_time0bk_err1'),
#  (0.024020629030178445, 'koi_time0bk_err2'),
#  (0.023758670011733964, 'koi_insol_err1'),
#  (0.02231462987325875, 'koi_period_err2'),
#  (0.02087478023936006, 'koi_impact'),
#  (0.019827440607126427, 'koi_period_err1'),
#  (0.018538029083482347, 'koi_insol'),
#  (0.018514834449038106, 'koi_teq'),
#  (0.01794255377744076, 'koi_time0bk'),
#  (0.01661007872399498, 'koi_srad_err1'),
#  (0.01650185373654179, 'koi_depth_err1'),
#  (0.01640074259073559, 'koi_insol_err2'),
#  (0.016083901367003, 'koi_depth_err2'),
#  (0.014312778909545, 'ra'),
#  (0.01386651392695021, 'dec'),
#  (0.013837406650642172, 'koi_impact_err1'),
#  (0.013676675233976698, 'koi_kepmag'),
#  (0.013657884995395332, 'koi_slogg_err2'),
#  (0.013425832293682891, 'koi_impact_err2'),
#  (0.012024215171348284, 'koi_steff'),
#  (0.011063811340147134, 'koi_srad'),
#  (0.01102731022443043, 'koi_slogg'),
#  (0.010964063285320555, 'koi_slogg_err1'),
#  (0.009818965287401185, 'koi_srad_err2'),
#  (0.0032446652088313505, 'koi_tce_plnt_num')]

# %% [markdown]
# # Pre-processing
#
# Scale the data using the MinMaxScaler and perform some feature selection

# %%
# Scale your data

# %% [markdown]
# # Train the Model

# %%
print(f"Training Data Score: {model2.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {model2.score(X_test_scaled, y_test)}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-4b90a93bf6fa> in <module>
# ----> 1 print(f"Training Data Score: {model2.score(X_train_scaled, y_train)}")
#       2 print(f"Testing Data Score: {model2.score(X_test_scaled, y_test)}")
#
# NameError: name 'model2' is not defined

# %% [markdown]
# # Hyperparameter Tuning
#
# Use `GridSearchCV` to tune the model's parameters

# %%
# Create the GridSearchCV model

# %%
# Train the model with GridSearch

# %%
print(grid2.best_params_)
print(grid2.best_score_)

# %% [markdown]
# # Save the Model

# %%
# save your model by updating "your_name" with your name
# and "your_model" with your model variable
# be sure to turn this in to BCS
# if joblib fails to import, try running the command to install in terminal/git-bash
import joblib
filename = 'model_random_forest.sav'
joblib.dump(your_model, filename)
